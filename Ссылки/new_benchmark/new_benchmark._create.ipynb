# %% [markdown]
# https://data.open-power-system-data.org/time_series/2020-10-06

# %% [markdown]
# ![image.png](attachment:097afdc3-89cc-471e-8ee1-8457776ee5d2.png)

# %%
# !wget https://data.open-power-system-data.org/time_series/2020-10-06/time_series_60min_singleindex.csv
# Out:
# --2024-05-12 10:06:45--  https://data.open-power-system-data.org/time_series/2020-10-06/time_series_60min_singleindex.csv
# Resolving data.open-power-system-data.org (data.open-power-system-data.org)... 85.13.131.68
# Connecting to data.open-power-system-data.org (data.open-power-system-data.org)|85.13.131.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130339665 (124M) [text/csv]
# Saving to: 'time_series_60min_singleindex.csv'
#
# time_series_60min_s 100%[===================>] 124.30M  25.7MB/s    in 5.6s
#
# 2024-05-12 10:06:51 (22.2 MB/s) - 'time_series_60min_singleindex.csv' saved [130339665/130339665]

# %%
import pandas as pd

df = pd.read_csv('/kaggle/working/time_series_60min_singleindex.csv')

# Выбор 10 колонок без пропусков
columns2 = df.columns[df.isnull().sum() < 2]
selected_columns = columns2[:50]

# Создание нового датафрейма только с выбранными колонками
df = df[selected_columns]
#df = df.iloc[:, 4:]
#df = df.iloc[:, :-3]
df_sel = df.dropna()
df.shape
# Out:
# (50401, 24)

# %%
df.sample()
# Out:
#               utc_timestamp        cet_cest_timestamp  \
# 23691  2017-09-14T02:00:00Z  2017-09-14T04:00:00+0200
#
#        AT_load_actual_entsoe_transparency  \
# 23691                              5464.0
#
#        AT_load_forecast_entsoe_transparency  \
# 23691                                5406.0
#
#        BE_load_actual_entsoe_transparency  DE_load_actual_entsoe_transparency  \
# 23691                              7817.0                             45921.0
#
#        DE_50hertz_load_actual_entsoe_transparency  \
# 23691                                      8505.0
#
#        DE_50hertz_load_forecast_entsoe_transparency  \
# 23691                                        7862.0
#
#        DE_50hertz_wind_generation_actual  \
# 23691                             9151.0
#
#        DE_50hertz_wind_offshore_generation_actual  ...  \
# 23691                                       314.0  ...
#
#        DE_tennet_load_actual_entsoe_transparency  \
# ...

# %% [markdown]
# **Варианты составления**

# %% [markdown]
# **1. DE_load_actual_entsoe_transparency: Общая нагрузка в Германии в МВ, как опубликовано на платформе прозрачности ENTSO-E**
# 2. DE_50hertz_load_actual_entsoe_transparency: Общая нагрузка в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 3. DE_50hertz_load_forecast_entsoe_transparency: Прогноз нагрузки на день вперед в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 4. DE_50hertz_wind_generation_actual: Фактическая генерация ветра в 50Hertz (контрольная зона) в МВ, рассчитано на основе данных ENTSO-E
# 5. DE_50hertz_wind_offshore_generation_actual: Фактическая генерация ветра на море в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 6. DE_50hertz_wind_onshore_generation_actual: Фактическая генерация ветра на суше в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 7. DE_amprion_load_actual_entsoe_transparency: Общая нагрузка в Amprion (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 8. DE_amprion_load_forecast_entsoe_transparency: Прогноз нагрузки на день вперед в Amprion (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 9. DE_amprion_wind_onshore_generation_actual: Фактическая генерация ветра на суше в Amprion (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 10. DE_tennet_load_actual_entsoe_transparency: Общая нагрузка в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 11. DE_tennet_load_forecast_entsoe_transparency: Прогноз нагрузки на день вперед в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 12. DE_tennet_wind_generation_actual: Фактическая генерация ветра в TenneT GER (контрольная зона) в МВ, рассчитано на основе данных ENTSO-E
# 13. DE_tennet_wind_offshore_generation_actual: Фактическая генерация ветра на море в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 14. DE_tennet_wind_onshore_generation_actual: Фактическая генерация ветра на суше в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 15. DE_transnetbw_load_actual_entsoe_transparency: Общая нагрузка в TransnetBW (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 16. DE_transnetbw_wind_onshore_generation_actual: Фактическая генерация ветра на суше в TransnetBW (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E

# %% [markdown]
# ## как раз 7

# %% [markdown]
# #### вариант 1
# 1. DE_load_actual_entsoe_transparency: Общая нагрузка в Германии в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 2. DE_50hertz_wind_offshore_generation_actual: Фактическая генерация ветра на море в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 3. DE_50hertz_wind_onshore_generation_actual: Фактическая генерация ветра на суше в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 4. DE_amprion_wind_onshore_generation_actual: Фактическая генерация ветра на суше в Amprion (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 5. DE_tennet_wind_offshore_generation_actual: Фактическая генерация ветра на море в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 6. DE_tennet_wind_oDE_transnetbw_wind_onshore_generation_actualnshore_generation_actual: Фактическая генерация ветра на суше в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 7. DE_transnetbw_wind_onshore_generation_actual: Фактическая генерация ветра на суше в TransnetBW (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E

# %% [markdown]
# #### вариант 2 (выбранный)
# **1. DE_load_actual_entsoe_transparency: Общая нагрузка в Германии в МВ, как опубликовано на платформе прозрачности ENTSO-E**
# 2. DE_50hertz_load_actual_entsoe_transparency: Общая нагрузка в 50Hertz (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 3. DE_amprion_load_actual_entsoe_transparency: Общая нагрузка в Amprion (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 4. DE_tennet_load_actual_entsoe_transparency: Общая нагрузка в TenneT GER (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 5. DE_transnetbw_load_actual_entsoe_transparency: Общая нагрузка в TransnetBW (контрольная зона) в МВ, как опубликовано на платформе прозрачности ENTSO-E
# 6. AT_load_actual_entsoe_transparency:   Общая нагрузка в Австрии
# 7. NL_load_actual_entsoe_transparency:   Общая нагрузка в Нидерландах

# %%
df = df[['utc_timestamp','DE_load_actual_entsoe_transparency','DE_50hertz_load_actual_entsoe_transparency',
         'DE_amprion_load_actual_entsoe_transparency','DE_tennet_load_actual_entsoe_transparency',
         'DE_transnetbw_load_actual_entsoe_transparency','AT_load_actual_entsoe_transparency',
         'NL_load_actual_entsoe_transparency']]
df
# Out:
#               utc_timestamp  DE_load_actual_entsoe_transparency  \
# 0      2014-12-31T23:00:00Z                                 NaN
# 1      2015-01-01T00:00:00Z                             41151.0
# 2      2015-01-01T01:00:00Z                             40135.0
# 3      2015-01-01T02:00:00Z                             39106.0
# 4      2015-01-01T03:00:00Z                             38765.0
# ...                     ...                                 ...
# 50396  2020-09-30T19:00:00Z                             57559.0
# 50397  2020-09-30T20:00:00Z                             54108.0
# 50398  2020-09-30T21:00:00Z                             49845.0
# 50399  2020-09-30T22:00:00Z                             46886.0
# 50400  2020-09-30T23:00:00Z                             45461.0
#
#        DE_50hertz_load_actual_entsoe_transparency  \
# 0                                             NaN
# 1                                          6839.0
# ...

# %%
df
# Out:
#               utc_timestamp  DE_load_actual_entsoe_transparency  \
# 0      2014-12-31T23:00:00Z                                 NaN
# 1      2015-01-01T00:00:00Z                             41151.0
# 2      2015-01-01T01:00:00Z                             40135.0
# 3      2015-01-01T02:00:00Z                             39106.0
# 4      2015-01-01T03:00:00Z                             38765.0
# ...                     ...                                 ...
# 50396  2020-09-30T19:00:00Z                             57559.0
# 50397  2020-09-30T20:00:00Z                             54108.0
# 50398  2020-09-30T21:00:00Z                             49845.0
# 50399  2020-09-30T22:00:00Z                             46886.0
# 50400  2020-09-30T23:00:00Z                             45461.0
#
#        DE_50hertz_load_actual_entsoe_transparency  \
# 0                                             NaN
# 1                                          6839.0
# ...

# %%
df.sample()
# Out:
#               utc_timestamp  DE_load_actual_entsoe_transparency  \
# 14178  2016-08-13T17:00:00Z                             48421.0
#
#        DE_50hertz_load_actual_entsoe_transparency  \
# 14178                                      9302.0
#
#        DE_amprion_load_actual_entsoe_transparency  \
# 14178                                     18492.0
#
#        DE_tennet_load_actual_entsoe_transparency  \
# 14178                                    15186.0
#
#        DE_transnetbw_load_actual_entsoe_transparency  \
# 14178                                         5441.0
#
#        AT_load_actual_entsoe_transparency  NL_load_actual_entsoe_transparency
# 14178                              5759.0                             11655.0

# %%
df['OT'] = df['DE_load_actual_entsoe_transparency'] # по принятым правилам
df['date'] = df['utc_timestamp']
df['date'] = pd.to_datetime(df['date']).dt.strftime('%Y-%m-%d %H:%M:%S')
date_column = df.pop('date')  # сохраняем столбец 'date'
df.insert(0, 'date', date_column)  # вставляем 'date' на первое место
df.drop(['utc_timestamp','DE_load_actual_entsoe_transparency'],axis=1,inplace=True)
df = df.drop(df.index[0])
df
# Out:
#                       date  DE_50hertz_load_actual_entsoe_transparency  \
# 1      2015-01-01 00:00:00                                      6839.0
# 2      2015-01-01 01:00:00                                      6955.0
# 3      2015-01-01 02:00:00                                      7094.0
# 4      2015-01-01 03:00:00                                      7364.0
# 5      2015-01-01 04:00:00                                      7992.0
# ...                    ...                                         ...
# 50396  2020-09-30 19:00:00                                     11153.0
# 50397  2020-09-30 20:00:00                                     10561.0
# 50398  2020-09-30 21:00:00                                      9836.0
# 50399  2020-09-30 22:00:00                                      9161.0
# 50400  2020-09-30 23:00:00                                      8857.0
#
#        DE_amprion_load_actual_entsoe_transparency  \
# 1                                         15163.0
# ...

# %%
df.describe()
# Out:
#        DE_50hertz_load_actual_entsoe_transparency  \
# count                                50400.000000
# mean                                 10404.450992
# std                                   1958.792338
# min                                    106.000000
# 25%                                   8908.000000
# 50%                                  10408.500000
# 75%                                  11951.000000
# max                                  16581.000000
#
#        DE_amprion_load_actual_entsoe_transparency  \
# count                                50400.000000
# mean                                 20943.023115
# std                                   3609.103489
# min                                  11598.000000
# 25%                                  17981.750000
# 50%                                  20880.000000
# 75%                                  24049.000000
# max                                  32060.000000
#
#        DE_tennet_load_actual_entsoe_transparency  \
# ...

# %%
de_small = df.iloc[6000:6966]
de_small.shape
# Out:
# (966, 8)

# %%
de_big = df.iloc[5000:22420]
de_big.shape
# Out:
# (17420, 8)

# %%
de_small.to_csv('de_small.csv')
de_big.to_csv('de_big.csv')

# %%
pd.read_csv('/kaggle/working/de_small.csv')
# Out:
#      Unnamed: 0                 date  \
# 0          6001  2015-09-08 00:00:00
# 1          6002  2015-09-08 01:00:00
# 2          6003  2015-09-08 02:00:00
# 3          6004  2015-09-08 03:00:00
# 4          6005  2015-09-08 04:00:00
# ..          ...                  ...
# 961        6962  2015-10-18 01:00:00
# 962        6963  2015-10-18 02:00:00
# 963        6964  2015-10-18 03:00:00
# 964        6965  2015-10-18 04:00:00
# 965        6966  2015-10-18 05:00:00
#
#      DE_50hertz_load_actual_entsoe_transparency  \
# 0                                        7414.0
# 1                                        7609.0
# 2                                        7971.0
# 3                                        8830.0
# 4                                       10171.0
# ..                                          ...
# 961                                      6498.0
# 962                                      6620.0
# 963                                      6652.0
# ...

# %%
pd.read_csv('/kaggle/working/de_big.csv')
# Out:
#        Unnamed: 0                 date  \
# 0            5001  2015-07-28 08:00:00
# 1            5002  2015-07-28 09:00:00
# 2            5003  2015-07-28 10:00:00
# 3            5004  2015-07-28 11:00:00
# 4            5005  2015-07-28 12:00:00
# ...           ...                  ...
# 17415       22416  2017-07-22 23:00:00
# 17416       22417  2017-07-23 00:00:00
# 17417       22418  2017-07-23 01:00:00
# 17418       22419  2017-07-23 02:00:00
# 17419       22420  2017-07-23 03:00:00
#
#        DE_50hertz_load_actual_entsoe_transparency  \
# 0                                         11984.0
# 1                                         12550.0
# 2                                         12270.0
# 3                                         11709.0
# 4                                         11731.0
# ...                                           ...
# 17415                                      7054.0
# 17416                                      6846.0
# ...

# %% [markdown]
# ### Дасеты сформированы по типу ETTh1 и national_illness

# %%
# !git clone https://github.com/zhouhaoyi/ETDataset -q
# !pip install --upgrade gdown -q #https://github.com/wkentaro/gdown/issues/333
# !gdown --fuzzy https://drive.google.com/file/d/1nXdMIJ7K201Bx3IBGNiaNFQ6FzeDEzIr/view?usp=drive_link -q
# !gdown --fuzzy https://drive.google.com/file/d/1rN79CxW3Vldp-WDuSoG0bKq9tYQR79UK/view?usp=drive_link -q
# !gdown --fuzzy https://drive.google.com/file/d/1WMKg7KevVEEd9jrfLG8mcpOequZMbjlM/view?usp=drive_link -q
# !unzip /kaggle/working/weather.zip
# !unzip /kaggle/working/exchange_rate.zip
# !unzip /kaggle/working/illness.zip
# Out:
# Archive:  /kaggle/working/weather.zip
#    creating: weather/
#   inflating: weather/weather.csv
# Archive:  /kaggle/working/exchange_rate.zip
#    creating: exchange_rate/
#   inflating: exchange_rate/.DS_Store
#   inflating: exchange_rate/exchange_rate.csv
# Archive:  /kaggle/working/illness.zip
#    creating: illness/
#   inflating: illness/national_illness.csv

# %%
pd.read_csv('/kaggle/working/illness/national_illness.csv')
# Out:
#                     date  % WEIGHTED ILI  %UNWEIGHTED ILI  AGE 0-4  AGE 5-24  \
# 0    2002-01-01 00:00:00        1.222620         1.166680      582       805
# 1    2002-01-08 00:00:00        1.333440         1.216500      683       872
# 2    2002-01-15 00:00:00        1.319290         1.130570      642       878
# 3    2002-01-22 00:00:00        1.494840         1.252460      728      1045
# 4    2002-01-29 00:00:00        1.471950         1.302370      823      1189
# ..                   ...             ...              ...      ...       ...
# 961  2020-06-02 00:00:00        0.839059         0.846722     2756      3528
# 962  2020-06-09 00:00:00        0.895958         0.908885     3203      3778
# 963  2020-06-16 00:00:00        0.910926         0.941625     3478      3796
# 964  2020-06-23 00:00:00        0.946945         0.972185     3734      3818
# 965  2020-06-30 00:00:00        0.963716         1.013760     3955      3843
#
#      ILITOTAL  NUM. OF PROVIDERS       OT
# ...

# %%
ETTh1 = pd.read_csv('/kaggle/working/ETDataset/ETT-small/ETTh1.csv')
ETTh1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17420 entries, 0 to 17419
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    17420 non-null  object
#  1   HUFL    17420 non-null  float64
#  2   HULL    17420 non-null  float64
#  3   MUFL    17420 non-null  float64
#  4   MULL    17420 non-null  float64
#  5   LUFL    17420 non-null  float64
#  6   LULL    17420 non-null  float64
#  7   OT      17420 non-null  float64
# dtypes: float64(7), object(1)
# memory usage: 1.1+ MB

# %%
ETTh1
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...
